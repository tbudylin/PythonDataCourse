# %% [markdown]
# # HW4 Part 2 - Building a RidgeRegression sklearn class
#
# April 21, 2020 | April is the cruelest month

# %% [markdown]
# This part of the assignment will be more difficult for those new to Python. It continues the class `LinearRegression` that was developed in lecture 4

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.linear_model import LinearRegression, Ridge

# %% [markdown]
# This part of the homework is more open ended, and builds off the LinearRegression sklearn class we went over in Lecture 4
#
# ## Building a custom Ridge Regression sklean class
#
# 1. Rewrite the fit() and predict() methods
# 2. Include get_parameters() and set_parameters() methods
# 3. Document the code properly
# 4. Test it on an example
#
# Make your class inherit properly from the relevant sklearn base classes (but not from the Ridge class). Feel free to look at the documentation of the Ridge class in sklearn to use similar variables/flags etc.
#
# Here are some resources:
#
# * https://towardsdatascience.com/building-a-custom-model-in-scikit-learn-b0da965a1299
#
# * https://scikit-learn.org/stable/developers/develop.html
#
# * https://towardsdatascience.com/ridge-and-lasso-regression-a-complete-guide-with-python-scikit-learn-e20e34bcbf0b
#
# * https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols_ridge_variance.html#sphx-glr-auto-examples-linear-model-plot-ols-ridge-variance-py

# %%
# rename class RidgeRegression so that it is not confused with the sklearn LinearRegression class
class RidgeRegression():
    """ 
    Ridge Regression
    
    
    Parameters
    ----------
    
    ??
        
    Attributes
    ----------
    m : scalar
        Estimated slope for the linear regression problem.
    
    b : ?
        ????????
        
    params : ?
        ????????
        
    See Also
    --------
    sklearn.linear_model.Lasso : The Lasso is a linear model that estimates
        sparse coefficients with l1 regularization.
    sklearn.linear_model.ElasticNet : Elastic-Net is a linear regression
        model trained with both l1 and l2 -norm regularization of the
        coefficients.
        
    Examples
    --------
    >>> import numpy as np
    >>> ???
    1.0
    
    """
    
    def __init__(self,fit_intercept=True):
        self.fit_intercept = fit_intercept
        
        # modify this
    
        
    def fit(self,x,y_data):
        
        # your code here
            
    def predict(self,x):

        # your code here

    def score(self,x,y):
        """ ?? """
        ss_res = np.sum((y - self.predict(x))**2) # residual sum of squares
        ss_tot = np.sum((y - np.mean(y))**2) # total sum of squares

        r2 = 1-ss_res/ss_tot
        
        return r2

# %% [markdown]
# # Test your class here
#
# You can use your own fake data or use the code below (from https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols_ridge_variance.html#sphx-glr-auto-examples-linear-model-plot-ols-ridge-variance-py)

# %%
print(__doc__)


# Code source: Gaël Varoquaux
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause


import numpy as np
import matplotlib.pyplot as plt

from sklearn import linear_model

X_train = np.c_[.5, 1].T
y_train = [.5, 1]
X_test = np.c_[0, 2].T

np.random.seed(0)

classifiers = dict(ols=linear_model.LinearRegression(),
                   ridge=RidgeRegression(alpha=.1)) # <<<<<<<< YOUR MODEL HERE

for name, clf in classifiers.items():
    fig, ax = plt.subplots(figsize=(4, 3))

    for _ in range(6):
        this_X = .1 * np.random.normal(size=(2, 1)) + X_train
        clf.fit(this_X, y_train)

        ax.plot(X_test, clf.predict(X_test), color='gray')
        ax.scatter(this_X, y_train, s=3, c='gray', marker='o', zorder=10)

    clf.fit(X_train, y_train)
    ax.plot(X_test, clf.predict(X_test), linewidth=2, color='blue')
    ax.scatter(X_train, y_train, s=30, c='red', marker='+', zorder=10)

    ax.set_title(name)
    ax.set_xlim(0, 2)
    ax.set_ylim((0, 1.6))
    ax.set_xlabel('X')
    ax.set_ylabel('y')

    fig.tight_layout()

plt.show()
